# %%
import nb_setup
import numpy as np
import matplotlib.pyplot as plt

from gpdm import GPDM
from dataset_utils.mocap_labels import RUN_TRIALS_TRAIN, RUN_TRIALS_TEST
import dataset_utils.select_joints as select_joints
# Out:
# <frozen importlib._bootstrap>:488: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# pygame 2.6.1 (SDL 2.30.7, Python 3.12.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
TRAIN_TRIALS = RUN_TRIALS_TRAIN
TEST_TRIALS = RUN_TRIALS_TEST
gpdm_save_name = "run_gpdm"

# %%
print(f"Number of train trials: {len(TRAIN_TRIALS)}")
print(f"Number of test trials: {len(TEST_TRIALS)}")
# Out:
# Number of train trials: 9
# Number of test trials: 18

# %%
reduced_columns = TRAIN_TRIALS[0].get_columns_for_joints(select_joints.WALKING_SIMPLIFIED_JOINTS)
DOFs = len(reduced_columns)
print(f"Number of DOFs: {DOFs}")
# Out:
# Number of DOFs: 35

# %%
train_dfs = [trial.as_dataframe() for trial in TRAIN_TRIALS]
train_arrs = [df[reduced_columns].to_numpy().astype(np.float32)[::5, :] for df in train_dfs]

# %%
d = 3 # latent space dimension
DOFs = len(reduced_columns)  # number of degrees of freedom

dyn_back_step = 1 # Number of time steps to look back in the dynamics GP

# Initial values for hyperparameters
y_lambdas_init = np.ones(DOFs)  # Signal standard deviation for observation GP
y_lengthscales_init = np.ones(d)  # Lengthscales for observation GP
y_sigma_n_init = 1e-2  # Noise standard deviation for observation GP

x_lambdas_init = np.ones(d)  # Signal standard deviation for latent dynamics GP
x_lengthscales_init = np.ones(dyn_back_step*d)  # Lengthscales for latent dynamics GP
x_sigma_n_init = 1e-2  # Noise standard deviation for latent dynamics GP
x_lin_coeff_init = np.ones(dyn_back_step*d + 1)  # Linear coefficients for latent dynamics GP

# %%
gpdm = GPDM(
        D=DOFs,
        d=d,
        dyn_target='full',
        dyn_back_step=dyn_back_step,
        y_lambdas_init=y_lambdas_init,
        y_lengthscales_init=y_lengthscales_init,
        y_sigma_n_init=y_sigma_n_init,
        x_lambdas_init=x_lambdas_init,
        x_lengthscales_init=x_lengthscales_init,
        x_sigma_n_init=x_sigma_n_init,
        x_lin_coeff_init=x_lin_coeff_init
    )

# %%
for train_arr in train_arrs[0:6]:
    gpdm.add_data(train_arr)

print('Num. of sequences = '+str(gpdm.num_sequences)+' [Data points = '+str(np.concatenate(gpdm.observations_list, 0).shape[0])+']')
# Out:
# Num. of sequences = 6 [Data points = 179]

# %%
gpdm.init_X()  
losses = gpdm.train_adam(num_opt_steps=1000, num_print_steps=10, lr=0.05)

gpdm.save(f'{gpdm_save_name}_config.pth', f'{gpdm_save_name}_state.pth')  

plt.plot(losses)
# Out:
# ### Model Training (Adam) ###
#
# GPDM Opt. EPOCH: 0
# Running loss: 4.8148e+06
# Update time: 0.10239291191101074
#
# GPDM Opt. EPOCH: 10
# Running loss: 1.7525e+06
# Update time: 0.3563237190246582
#
# GPDM Opt. EPOCH: 20
# Running loss: 7.4772e+05
# Update time: 0.37213778495788574
#
# GPDM Opt. EPOCH: 30
# Running loss: 3.7341e+05
# Update time: 0.2649800777435303
# Running loss: -2.8455e+04
# Update time: 0.30432939529418945
#
# GPDM Opt. EPOCH: 700
# Running loss: -2.8529e+04
# Update time: 0.2845492362976074
#
# GPDM Opt. EPOCH: 710
# Running loss: -2.8601e+04
# Update time: 0.2965686321258545
#
# GPDM Opt. EPOCH: 720
# Running loss: -2.8672e+04
# Update time: 0.2943458557128906
#
# GPDM Opt. EPOCH: 730
# Running loss: -2.8742e+04
# Update time: 0.3056983947753906
#
# GPDM Opt. EPOCH: 740
# Running loss: -2.8811e+04
# Update time: 0.3037431240081787
#
# GPDM Opt. EPOCH: 750
# Running loss: -2.8879e+04
# Update time: 0.4045548439025879
#
# GPDM Opt. EPOCH: 760
# Running loss: -2.8948e+04
# Update time: 0.358306884765625
#
# GPDM Opt. EPOCH: 770
# Running loss: -2.9015e+04
# Update time: 0.306384801864624
#
# GPDM Opt. EPOCH: 780
# Running loss: -2.9083e+04
# Update time: 0.3077211380004883
#
# GPDM Opt. EPOCH: 790
# Running loss: -2.9150e+04
# Update time: 0.3350052833557129
#
# GPDM Opt. EPOCH: 800
# Running loss: -2.9217e+04
# Update time: 0.5602877140045166
#
# GPDM Opt. EPOCH: 810
# Running loss: -2.9283e+04
# Update time: 0.35527491569519043
#
# GPDM Opt. EPOCH: 820
# Running loss: -2.9350e+04
# Update time: 0.4070699214935303
#
# GPDM Opt. EPOCH: 830
# Running loss: -2.9416e+04
# Update time: 0.2996389865875244
#
# GPDM Opt. EPOCH: 840
# Running loss: -2.9482e+04
# Update time: 0.31673455238342285
#
# GPDM Opt. EPOCH: 850
# Running loss: -2.9548e+04
# Update time: 0.3144993782043457
#
# GPDM Opt. EPOCH: 860
# Running loss: -2.9614e+04
# Update time: 0.31848788261413574
#
# GPDM Opt. EPOCH: 870
# Running loss: -2.9680e+04
# Update time: 0.3064889907836914
#
# GPDM Opt. EPOCH: 880
# Running loss: -2.9746e+04
# Update time: 0.3158409595489502
#
# GPDM Opt. EPOCH: 890
# Running loss: -2.9812e+04
# Update time: 0.47039055824279785
#
# GPDM Opt. EPOCH: 900
# Running loss: -2.9879e+04
# Update time: 0.3157992362976074
#
# GPDM Opt. EPOCH: 910
# Running loss: -2.9945e+04
# Update time: 0.32540154457092285
#
# GPDM Opt. EPOCH: 920
# Running loss: -3.0011e+04
# Update time: 0.3144519329071045
#
# GPDM Opt. EPOCH: 930
# Running loss: -3.0077e+04
# Update time: 0.4163703918457031
#
# GPDM Opt. EPOCH: 940
# Running loss: -3.0144e+04
# Update time: 0.5211973190307617
#
# GPDM Opt. EPOCH: 950
# Running loss: -3.0210e+04
# Update time: 0.6563620567321777
#
# GPDM Opt. EPOCH: 960
# Running loss: -3.0277e+04
# Update time: 0.7048332691192627
#
# GPDM Opt. EPOCH: 970
# Running loss: -3.0344e+04
# Update time: 0.427379846572876
#
# GPDM Opt. EPOCH: 980
# Running loss: -3.0411e+04
# Update time: 0.3765602111816406
#
# GPDM Opt. EPOCH: 990
# Running loss: -3.0478e+04
# Update time: 0.4483816623687744
#
# GPDM config dict saved in run_gpdm_config.pth
# GPDM state dict saved in run_gpdm_state.pth

# %%
# Plot the latent space
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
X = gpdm.X.detach().numpy()
ax.plot(X[:, 0], X[:, 1], X[:, 2])
