# %%
import numpy as np
import matplotlib.pyplot as plt

from gpdm import GPDM
from dataset_utils.mocap_labels import WALK_TRIALS_TRAIN, WALK_TRIALS_TEST
import dataset_utils.select_joints as select_joints
# Out:
# <frozen importlib._bootstrap>:488: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# pygame 2.6.1 (SDL 2.30.7, Python 3.12.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
TRAIN_TRIALS = WALK_TRIALS_TRAIN
TEST_TRIALS = WALK_TRIALS_TEST
gpdm_save_name = "walk_gpdm"

# %%
print(f"Number of train trials: {len(TRAIN_TRIALS)}")
print(f"Number of test trials: {len(TEST_TRIALS)}")
# Out:
# Number of train trials: 10
# Number of test trials: 21

# %%
reduced_columns = TRAIN_TRIALS[0].get_columns_for_joints(select_joints.WALKING_SIMPLIFIED_JOINTS)
DOFs = len(reduced_columns)
print(f"Number of DOFs: {DOFs}")
# Out:
# Number of DOFs: 35

# %%
train_dfs = [trial.as_dataframe() for trial in TRAIN_TRIALS]
train_arrs = [df[reduced_columns].to_numpy().astype(np.float32)[::5, :] for df in train_dfs]

# %%
d = 3 # latent space dimension
DOFs = len(reduced_columns)  # number of degrees of freedom

dyn_back_step = 1 # Number of time steps to look back in the dynamics GP

# Initial values for hyperparameters
y_lambdas_init = np.ones(DOFs)  # Signal standard deviation for observation GP
y_lengthscales_init = np.ones(d)  # Lengthscales for observation GP
y_sigma_n_init = 1e-2  # Noise standard deviation for observation GP

x_lambdas_init = np.ones(d)  # Signal standard deviation for latent dynamics GP
x_lengthscales_init = np.ones(dyn_back_step*d)  # Lengthscales for latent dynamics GP
x_sigma_n_init = 1e-2  # Noise standard deviation for latent dynamics GP
x_lin_coeff_init = np.ones(dyn_back_step*d + 1)  # Linear coefficients for latent dynamics GP

# %%
gpdm = GPDM(
        D=DOFs,
        d=d,
        dyn_target='full',
        dyn_back_step=dyn_back_step,
        y_lambdas_init=y_lambdas_init,
        y_lengthscales_init=y_lengthscales_init,
        y_sigma_n_init=y_sigma_n_init,
        x_lambdas_init=x_lambdas_init,
        x_lengthscales_init=x_lengthscales_init,
        x_sigma_n_init=x_sigma_n_init,
        x_lin_coeff_init=x_lin_coeff_init
    )

# %%
for train_arr in train_arrs:
    gpdm.add_data(train_arr)

print('Num. of sequences = '+str(gpdm.num_sequences)+' [Data points = '+str(np.concatenate(gpdm.observations_list, 0).shape[0])+']')
# Out:
# Num. of sequences = 10 [Data points = 678]

# %%
gpdm.init_X()  
losses = gpdm.train_adam(num_opt_steps=1000, num_print_steps=10, lr=0.05)

gpdm.save(f'{gpdm_save_name}_config.pth', f'{gpdm_save_name}_state.pth')  

plt.plot(losses)
# Out:
# ### Model Training (Adam) ###
#
# GPDM Opt. EPOCH: 0
# Running loss: 9.5614e+06
# Update time: 0.9628691673278809
#
# GPDM Opt. EPOCH: 10
# Running loss: 2.9408e+06
# Update time: 13.929967641830444
#
# GPDM Opt. EPOCH: 20
# Running loss: 1.2211e+06
# Update time: 11.965118169784546
#
# GPDM Opt. EPOCH: 30
# Running loss: 6.1524e+05
# Update time: 7.282299995422363
# Update time: 4.7500998973846436
#
# GPDM Opt. EPOCH: 700
# Running loss: -1.0983e+05
# Update time: 3.0119893550872803
#
# GPDM Opt. EPOCH: 710
# Running loss: -1.1006e+05
# Update time: 3.9023938179016113
#
# GPDM Opt. EPOCH: 720
# Running loss: -1.1028e+05
# Update time: 2.938904047012329
#
# GPDM Opt. EPOCH: 730
# Running loss: -1.1050e+05
# Update time: 3.1538496017456055
#
# GPDM Opt. EPOCH: 740
# Running loss: -1.1070e+05
# Update time: 3.0910627841949463
#
# GPDM Opt. EPOCH: 750
# Running loss: -1.1091e+05
# Update time: 5.312637805938721
#
# GPDM Opt. EPOCH: 760
# Running loss: -1.1111e+05
# Update time: 6.49090051651001
#
# GPDM Opt. EPOCH: 770
# Running loss: -1.1131e+05
# Update time: 5.65001106262207
#
# GPDM Opt. EPOCH: 780
# Running loss: -1.1150e+05
# Update time: 5.8902366161346436
#
# GPDM Opt. EPOCH: 790
# Running loss: -1.1169e+05
# Update time: 6.0541322231292725
#
# GPDM Opt. EPOCH: 800
# Running loss: -1.1189e+05
# Update time: 6.3525190353393555
#
# GPDM Opt. EPOCH: 810
# Running loss: -1.1208e+05
# Update time: 5.8127453327178955
#
# GPDM Opt. EPOCH: 820
# Running loss: -1.1228e+05
# Update time: 6.20319676399231
#
# GPDM Opt. EPOCH: 830
# Running loss: -1.1247e+05
# Update time: 5.823123931884766
#
# GPDM Opt. EPOCH: 840
# Running loss: -1.1266e+05
# Update time: 5.888395309448242
#
# GPDM Opt. EPOCH: 850
# Running loss: -1.1285e+05
# Update time: 6.4620442390441895
#
# GPDM Opt. EPOCH: 860
# Running loss: -1.1305e+05
# Update time: 6.3645806312561035
#
# GPDM Opt. EPOCH: 870
# Running loss: -1.1324e+05
# Update time: 5.7676842212677
#
# GPDM Opt. EPOCH: 880
# Running loss: -1.1343e+05
# Update time: 5.84908652305603
#
# GPDM Opt. EPOCH: 890
# Running loss: -1.1362e+05
# Update time: 5.89968204498291
#
# GPDM Opt. EPOCH: 900
# Running loss: -1.1381e+05
# Update time: 6.718651294708252
#
# GPDM Opt. EPOCH: 910
# Running loss: -1.1400e+05
# Update time: 5.411161422729492
#
# GPDM Opt. EPOCH: 920
# Running loss: -1.1419e+05
# Update time: 3.1323978900909424
#
# GPDM Opt. EPOCH: 930
# Running loss: -1.1438e+05
# Update time: 5.720725774765015
#
# GPDM Opt. EPOCH: 940
# Running loss: -1.1457e+05
# Update time: 5.844658136367798
#
# GPDM Opt. EPOCH: 950
# Running loss: -1.1476e+05
# Update time: 5.800487041473389
#
# GPDM Opt. EPOCH: 960
# Running loss: -1.1495e+05
# Update time: 5.8490986824035645
#
# GPDM Opt. EPOCH: 970
# Running loss: -1.1515e+05
# Update time: 5.947939157485962
#
# GPDM Opt. EPOCH: 980
# Running loss: -1.1534e+05
# Update time: 5.750542163848877
#
# GPDM Opt. EPOCH: 990
# Running loss: -1.1554e+05
# Update time: 5.763901233673096
#
# GPDM config dict saved in walk_gpdm_config.pth
# GPDM state dict saved in walk_gpdm_state.pth

# %%
# Plot the latent space
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
X = gpdm.X.detach().numpy()
ax.plot(X[:, 0], X[:, 1], X[:, 2])
